# %% [markdown]
# <a href="https://colab.research.google.com/github/Oblum1989/NumPy/blob/master/fastapi_torch_challenges.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#instalaciones

#!pip3 install torchrec-nightly

# !pip install fastapi
# !pip install streamlit
# !npm install -g localtunnel
# !pip install pyngrok
# !pip install uvicorn[standard]
# !pip install ssl
# !pip install pandas
# Out:
# Collecting fastapi
#   Using cached fastapi-0.103.2-py3-none-any.whl (66 kB)
# Collecting anyio<4.0.0,>=3.7.1
#   Downloading anyio-3.7.1-py3-none-any.whl (80 kB)
#      |████████████████████████████████| 80 kB 6.5 MB/s
# Collecting pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4
#   Downloading pydantic-2.4.2-py3-none-any.whl (395 kB)
#      |████████████████████████████████| 395 kB 32.6 MB/s
# Collecting typing-extensions>=4.5.0
#   Downloading typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Collecting starlette<0.28.0,>=0.27.0
#   Using cached starlette-0.27.0-py3-none-any.whl (66 kB)
# Collecting exceptiongroup; python_version < "3.11"
#   Downloading exceptiongroup-1.1.3-py3-none-any.whl (14 kB)
# Collecting sniffio>=1.1
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.7/site-packages (from anyio<4.0.0,>=3.7.1->fastapi) (2.10)
# Collecting pydantic-core==2.10.1
#   Downloading pydantic_core-2.10.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 34.5 MB/s
# Collecting annotated-types>=0.4.0
#   Downloading annotated_types-0.5.0-py3-none-any.whl (11 kB)
# Installing collected packages: exceptiongroup, sniffio, typing-extensions, anyio, pydantic-core, annotated-types, pydantic, starlette, fastapi
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.3.0
#     Uninstalling typing-extensions-4.3.0:
#       Successfully uninstalled typing-extensions-4.3.0
# Successfully installed annotated-types-0.5.0 anyio-3.7.1 exceptiongroup-1.1.3 fastapi-0.103.2 pydantic-2.4.2 pydantic-core-2.10.1 sniffio-1.3.0 starlette-0.27.0 typing-extensions-4.7.1
# Collecting streamlit
#   Downloading streamlit-1.23.1-py2.py3-none-any.whl (8.9 MB)
#      |████████████████████████████████| 8.9 MB 22.3 MB/s
# Collecting validators<1,>=0.2
#   Downloading validators-0.20.0.tar.gz (30 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.7/site-packages (from streamlit) (1.19.2)
# Collecting watchdog; platform_system != "Darwin"
#   Using cached watchdog-3.0.0-py3-none-manylinux2014_x86_64.whl (82 kB)
# Collecting tenacity<9,>=8.0.0
#   Downloading tenacity-8.2.3-py3-none-any.whl (24 kB)
# Collecting cachetools<6,>=4.0
#   Downloading cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Collecting python-dateutil<3,>=2
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
#      |████████████████████████████████| 247 kB 69.4 MB/s
# Collecting click<9,>=7.0
#   Downloading click-8.1.7-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 5.9 MB/s
# Collecting toml<2
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting pandas<3,>=0.25
#   Downloading pandas-1.3.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 46.0 MB/s
# Collecting blinker<2,>=1.0.0
#   Downloading blinker-1.6.2-py3-none-any.whl (13 kB)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in /usr/local/lib/python3.7/site-packages (from streamlit) (4.11.3)
# Collecting gitpython!=3.1.19,<4,>=3
#   Using cached GitPython-3.1.37-py3-none-any.whl (190 kB)
# Collecting protobuf<5,>=3.20
#   Downloading protobuf-4.24.3-cp37-abi3-manylinux2014_x86_64.whl (311 kB)
#      |████████████████████████████████| 311 kB 28.2 MB/s
# Collecting pyarrow>=4.0
#   Downloading pyarrow-12.0.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (39.1 MB)
#      |████████████████████████████████| 39.1 MB 1.3 MB/s
# Collecting rich<14,>=10.11.0
#   Downloading rich-13.5.3-py3-none-any.whl (239 kB)
#      |████████████████████████████████| 239 kB 57.3 MB/s
# Collecting pydeck<1,>=0.1.dev5
#   Using cached pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
# Collecting pympler<2,>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      |████████████████████████████████| 164 kB 56.3 MB/s
# Collecting tzlocal<5,>=1.1
#   Downloading tzlocal-4.3.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: requests<3,>=2.4 in /usr/local/lib/python3.7/site-packages (from streamlit) (2.24.0)
# Collecting packaging<24,>=14.1
#   Downloading packaging-23.1-py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 4.0 MB/s
# Collecting pillow<10,>=6.2.0
#   Downloading Pillow-9.5.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 59.3 MB/s
# Collecting altair<6,>=4.0
#   Downloading altair-5.0.1-py3-none-any.whl (471 kB)
#      |████████████████████████████████| 471 kB 55.8 MB/s
# Requirement already satisfied: typing-extensions<5,>=4.0.1 in /usr/local/lib/python3.7/site-packages (from streamlit) (4.7.1)
# Collecting tornado<7,>=6.0.3
#   Downloading tornado-6.2-cp37-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (423 kB)
#      |████████████████████████████████| 423 kB 59.4 MB/s
# Collecting decorator>=3.4.0
#   Downloading decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/site-packages (from python-dateutil<3,>=2->streamlit) (1.15.0)
# Collecting pytz>=2017.3
#   Downloading pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
#      |████████████████████████████████| 502 kB 58.7 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/site-packages (from importlib-metadata<7,>=1.4->streamlit) (3.11.0)
# Collecting gitdb<5,>=4.0.1
#   Using cached gitdb-4.0.10-py3-none-any.whl (62 kB)
# Collecting pygments<3.0.0,>=2.13.0
#   Downloading Pygments-2.16.1-py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 63.1 MB/s
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-2.2.0-py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 2.4 MB/s
# Collecting jinja2>=2.10.1
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 70.5 MB/s
# Collecting backports.zoneinfo; python_version < "3.9"
#   Downloading backports.zoneinfo-0.2.1-cp37-cp37m-manylinux1_x86_64.whl (70 kB)
#      |████████████████████████████████| 70 kB 6.3 MB/s
# Collecting pytz-deprecation-shim
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/site-packages (from requests<3,>=2.4->streamlit) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/site-packages (from requests<3,>=2.4->streamlit) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/site-packages (from requests<3,>=2.4->streamlit) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/site-packages (from requests<3,>=2.4->streamlit) (1.25.11)
# Requirement already satisfied: toolz in /usr/local/lib/python3.7/site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Collecting jsonschema>=3.0
#   Downloading jsonschema-4.17.3-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 7.1 MB/s
# Collecting smmap<6,>=3.0.1
#   Using cached smmap-5.0.1-py3-none-any.whl (24 kB)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting tzdata; python_version >= "3.6"
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      |████████████████████████████████| 341 kB 83.9 MB/s
# Collecting pkgutil-resolve-name>=1.3.10; python_version < "3.9"
#   Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl (4.7 kB)
# Collecting importlib-resources>=1.4.0; python_version < "3.9"
#   Downloading importlib_resources-5.12.0-py3-none-any.whl (36 kB)
# Collecting attrs>=17.4.0
#   Downloading attrs-23.1.0-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 6.5 MB/s
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
#   Downloading pyrsistent-0.19.3-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 4.3 MB/s
# Building wheels for collected packages: validators
#   Building wheel for validators (setup.py) ... done
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19565 sha256=47739524c1ab3db01b1e10e171479d38d471257972fbbd7271c64efcdade8d23
#   Stored in directory: /root/.cache/pip/wheels/5f/55/ab/36a76989f7f88d9ca7b1f68da6d94252bb6a8d6ad4f18e04e9
# Successfully built validators
# Installing collected packages: decorator, validators, watchdog, tenacity, cachetools, python-dateutil, click, toml, pytz, pandas, blinker, smmap, gitdb, gitpython, protobuf, pyarrow, pygments, mdurl, markdown-it-py, rich, MarkupSafe, jinja2, pydeck, pympler, backports.zoneinfo, tzdata, pytz-deprecation-shim, tzlocal, packaging, pillow, pkgutil-resolve-name, importlib-resources, attrs, pyrsistent, jsonschema, altair, tornado, streamlit
# Successfully installed MarkupSafe-2.1.3 altair-5.0.1 attrs-23.1.0 backports.zoneinfo-0.2.1 blinker-1.6.2 cachetools-5.3.1 click-8.1.7 decorator-5.1.1 gitdb-4.0.10 gitpython-3.1.37 importlib-resources-5.12.0 jinja2-3.1.2 jsonschema-4.17.3 markdown-it-py-2.2.0 mdurl-0.1.2 packaging-23.1 pandas-1.3.5 pillow-9.5.0 pkgutil-resolve-name-1.3.10 protobuf-4.24.3 pyarrow-12.0.1 pydeck-0.8.1b0 pygments-2.16.1 pympler-1.0.1 pyrsistent-0.19.3 python-dateutil-2.8.2 pytz-2023.3.post1 pytz-deprecation-shim-0.1.0.post0 rich-13.5.3 smmap-5.0.1 streamlit-1.23.1 tenacity-8.2.3 toml-0.10.2 tornado-6.2 tzdata-2023.3 tzlocal-4.3.1 validators-0.20.0 watchdog-3.0.0
# /tools/node/bin/lt -> /tools/node/lib/node_modules/localtunnel/bin/lt.js
# + localtunnel@2.0.2
# updated 1 package in 1.032s
#
#
#    ╭────────────────────────────────────────────────────────────────╮
#    │                                                                │
#    │      New major version of npm available! 6.14.8 → 10.1.0       │
#    │   Changelog: https://github.com/npm/cli/releases/tag/v10.1.0   │
#    │               Run npm install -g npm to update!                │
#    │                                                                │
#    ╰────────────────────────────────────────────────────────────────╯
#
# Collecting pyngrok
#   Using cached pyngrok-7.0.0.tar.gz (718 kB)
# Collecting PyYAML
#   Downloading PyYAML-6.0.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (670 kB)
#      |████████████████████████████████| 670 kB 16.1 MB/s
# Building wheels for collected packages: pyngrok
#   Building wheel for pyngrok (setup.py) ... done
#   Created wheel for pyngrok: filename=pyngrok-7.0.0-py3-none-any.whl size=21132 sha256=f92d8496425a3a45dc8db8a96dbe354ec79546626c91b46dc74ee1c6ddfc4414
#   Stored in directory: /root/.cache/pip/wheels/b3/4b/81/6aad05a0b0c0df6d6eb4cfd7c5f94b46ad1a5519b5bc41f09d
# Successfully built pyngrok
# Installing collected packages: PyYAML, pyngrok
# Successfully installed PyYAML-6.0.1 pyngrok-7.0.0
# Collecting uvicorn[standard]
#   Downloading uvicorn-0.22.0-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 4.1 MB/s
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /usr/local/lib/python3.7/site-packages (from uvicorn[standard]) (4.7.1)
# Collecting h11>=0.8
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.7/site-packages (from uvicorn[standard]) (8.1.7)
# Collecting watchfiles>=0.13; extra == "standard"
#   Using cached watchfiles-0.20.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0; sys_platform != "win32" and (sys_platform != "cygwin" and platform_python_implementation != "PyPy") and extra == "standard"
#   Downloading uvloop-0.17.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 62.6 MB/s
# Collecting python-dotenv>=0.13; extra == "standard"
#   Downloading python_dotenv-0.21.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: pyyaml>=5.1; extra == "standard" in /usr/local/lib/python3.7/site-packages (from uvicorn[standard]) (6.0.1)
# Collecting websockets>=10.4; extra == "standard"
#   Downloading websockets-11.0.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      |████████████████████████████████| 129 kB 52.3 MB/s
# Collecting httptools>=0.5.0; extra == "standard"
#   Downloading httptools-0.6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (419 kB)
#      |████████████████████████████████| 419 kB 41.5 MB/s
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/site-packages (from click>=7.0->uvicorn[standard]) (4.11.3)
# Requirement already satisfied: anyio>=3.0.0 in /usr/local/lib/python3.7/site-packages (from watchfiles>=0.13; extra == "standard"->uvicorn[standard]) (3.7.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->click>=7.0->uvicorn[standard]) (3.11.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.7/site-packages (from anyio>=3.0.0->watchfiles>=0.13; extra == "standard"->uvicorn[standard]) (1.3.0)
# Requirement already satisfied: exceptiongroup; python_version < "3.11" in /usr/local/lib/python3.7/site-packages (from anyio>=3.0.0->watchfiles>=0.13; extra == "standard"->uvicorn[standard]) (1.1.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.7/site-packages (from anyio>=3.0.0->watchfiles>=0.13; extra == "standard"->uvicorn[standard]) (2.10)
# Installing collected packages: h11, watchfiles, uvloop, python-dotenv, websockets, httptools, uvicorn
# Successfully installed h11-0.14.0 httptools-0.6.0 python-dotenv-0.21.1 uvicorn-0.22.0 uvloop-0.17.0 watchfiles-0.20.0 websockets-11.0.3
# Collecting ssl
#   Using cached ssl-1.16.tar.gz (33 kB)
# ERROR: Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.17.3; platform_machine != "aarch64" and platform_machine != "arm64" and python_version < "3.10" in /usr/local/lib/python3.7/site-packages (from pandas) (1.19.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
import uvicorn
from typing import Union, Dict
from fastapi import FastAPI, Response, Depends


#from fastapi.encoders import jsonable_encoder
#from fastapi.responses import JSONResponse
from pydantic import BaseModel
import asyncio

import IPython
#from IPython.display import data
import google.colab
from google.colab import output
#import pandas

# %%
from IPython.display import Javascript
display(Javascript('''
(async () => {
  google.colab.kernel.comms.registerTarget('comms_testing', (comm, message) => {
    comm.send('this is the response', {buffers: message.buffers});
    document.body.appendChild(document.createTextNode('comm opened.'))
  });
})()'''))

from ipykernel import comm
buffer = b'hello world'
channel = comm.Comm(target_name='comms_testing', data={'foo': 1}, buffers=[buffer])

message = None
def handle_message(msg):
  global message
  message = msg

channel.on_msg(handle_message)

# %%
# !wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.9.2-Linux-x86_64.sh
# !chmod +x Miniconda3-py37_4.9.2-Linux-x86_64.sh
# !bash ./Miniconda3-py37_4.9.2-Linux-x86_64.sh -b -f -p /usr/local
# Out:
# --2023-09-29 19:31:19--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.9.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 90040905 (86M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.9.2-Linux-x86_64.sh.1’
#
# Miniconda3-py37_4.9 100%[===================>]  85.87M   169MB/s    in 0.5s
#
# 2023-09-29 19:31:20 (169 MB/s) - ‘Miniconda3-py37_4.9.2-Linux-x86_64.sh.1’ saved [90040905/90040905]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - brotlipy==0.7.0=py37h27cfd23_1003
#     - ca-certificates==2020.10.14=0
#     - certifi==2020.6.20=pyhd3eb1b0_3
#     - cffi==1.14.3=py37h261ae71_2
#     - chardet==3.0.4=py37h06a4308_1003
#     - conda-package-handling==1.7.2=py37h03888b9_0
#     - conda==4.9.2=py37h06a4308_0
#     - cryptography==3.2.1=py37h3c74f83_1
#     - idna==2.10=py_0
#     - ld_impl_linux-64==2.33.1=h53a641e_7
#     - libedit==3.1.20191231=h14c3975_1
#     - libffi==3.3=he6710b0_2
#     - libgcc-ng==9.1.0=hdf63c60_0
#     - libstdcxx-ng==9.1.0=hdf63c60_0
#     - ncurses==6.2=he6710b0_1
#     - openssl==1.1.1h=h7b6447c_0
#     - pip==20.2.4=py37h06a4308_0
#     - pycosat==0.6.3=py37h27cfd23_0
#     - pycparser==2.20=py_2
#     - pyopenssl==19.1.0=pyhd3eb1b0_1
#     - pysocks==1.7.1=py37_1
#     - python==3.7.9=h7579374_0
#     - readline==8.0=h7b6447c_0
#     - requests==2.24.0=py_0
#     - ruamel_yaml==0.15.87=py37h7b6447c_1
#     - setuptools==50.3.1=py37h06a4308_1
#     - six==1.15.0=py37h06a4308_0
#     - sqlite==3.33.0=h62c20be_0
#     - tk==8.6.10=hbc83047_0
#     - tqdm==4.51.0=pyhd3eb1b0_0
#     - urllib3==1.25.11=py_0
#     - wheel==0.35.1=pyhd3eb1b0_0
#     - xz==5.2.5=h7b6447c_0
#     - yaml==0.2.5=h7b6447c_0
#     - zlib==1.2.11=h7b6447c_3
#
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            pkgs/main/linux-64::certifi-2022.12.7~ --> pkgs/main/noarch::certifi-2020.6.20-pyhd3eb1b0_3
#
# The following packages will be DOWNGRADED:
#
#   ca-certificates                     2023.08.22-h06a4308_0 --> 2020.10.14-0
#   conda                               23.1.0-py37h06a4308_0 --> 4.9.2-py37h06a4308_0
#   openssl                                 1.1.1w-h7f8727e_0 --> 1.1.1h-h7b6447c_0
#
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local

# %%
# !conda install pytorch pytorch-cuda=11.8 -c pytorch-nightly -c nvidia -y
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 23.7.4
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - pytorch
#     - pytorch-cuda=11.8
#
#
# The following packages will be UPDATED:
#
#   ca-certificates                              2020.10.14-0 --> 2023.08.22-h06a4308_0
#   openssl                                 1.1.1h-h7b6447c_0 --> 1.1.1w-h7f8727e_0
#
#
# done
# done
# done

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
# !cp /usr/local/lib/lib* /usr/lib/

# %%
#importaciones
import os
import torch
import torch.nn as nn
import torch.optim as optim
import torch.distributed as dist
import csv
import ast
from torch.utils.data import Dataset, DataLoader
import requests
import pprint
import sys
sys.path = ['', '/env/python', '/usr/local/lib/python37.zip', '/usr/local/lib/python3.7', '/usr/local/lib/python3.7/lib-dynload', '/usr/local/lib/python3.7/site-packages']

import portpicker
import threading
import socket
import IPython

from six.moves import socketserver
from six.moves import SimpleHTTPServer

# %%
#carga del modelo de Torch
class UserItemDataset(Dataset):
    def __init__(self, user_data, item_data, ratings):
        self.user_data = torch.LongTensor(user_data)
        self.item_data = torch.LongTensor(item_data)
        self.ratings = torch.FloatTensor(ratings) #cambiar esto por varios parametros

    def __len__(self):
        return len(self.ratings)

    def __getitem__(self, idx):
        user = self.user_data[idx]
        item = self.item_data[idx]
        rating = self.ratings[idx] #Parámetros deseados: %desafíos realizados en la habilidad correspondiente
        return user, item, rating

# definimos la clase para recomendar y para ser recomendado
class recommender(nn.Module):
    def __init__(self, num_users, num_items, embedding_dim): #van 3 parámetros
        super(recommender, self).__init__()
        self.user_embedding = nn.Embedding(num_users, embedding_dim)
        self.item_embedding = nn.Embedding(num_items, embedding_dim)
        self.fc = nn.Linear(embedding_dim * 2, 1)

    def forward(self, user, item):
        user_embed = self.user_embedding(user)
        item_embed = self.item_embedding(item)
        concat_embed = torch.cat([user_embed, item_embed], dim=1)
        output = self.fc(concat_embed)
        return output.squeeze()

# %%
#cargar base de datos (!pendiente, conexión de verdad)
user_data=[] # ID de grupo
ratings = [] # Respuestas habilidades

with open('boldinnGroups.csv') as csv_file:
  csv_reader = csv.reader(csv_file, delimiter=',')
  line_count = 0
  for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            float1 = float(row[0])
            int1 = round(float1)
            user_data.append(int1)
            data2_dict = ast.literal_eval(row[2])
            ratings = list(data2_dict.values())
            rounded_ratings = [round(value, 2) for value in ratings]
            line_count += 1
print(f'Processed {line_count} lines.')
#for i in ratings: ratings[i] = round(ratings[i])   !pendiente redondear!

print(f'\t{user_data} has the criteria {rounded_ratings}.')


item_data=[]
# task IDs (usar "code")
with open('boldinnTasks.csv') as csv_file:
  csv_reader = csv.reader(csv_file, delimiter=',')
  line_count = 0
  for row in csv_reader:
    if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
    else:
            print(f'\t{row[0]} has the criteria {row[3]}')
            item_data.append(round(float(row[3])))
            line_count += 1
  print(f'Processed {line_count} lines.')



#carga de los datos en una lista
dataset = UserItemDataset(user_data, item_data, rounded_ratings)
dataloader = DataLoader(dataset, batch_size=10, shuffle=False)
# Out:
# Column names are group_id, ability_answers, criterion_answers
# Processed 36 lines.
# 	[6, 4, 36, 15, 12, 26, 24, 34, 95, 38, 33, 17, 35, 32, 28, 29, 101, 30, 103, 40, 39, 81, 79, 14, 112, 20, 113, 114, 115, 117, 116, 118, 119, 80, 9] has the criteria [42.86, 57.14, 42.86, 57.14, 42.86, 57.14, 42.86, 57.14, 42.86, 57.14, 42.86, 57.14, 57.14, 42.86, 57.14, 42.86, 57.14, 57.14, 57.14, 57.14].
# Column names are code, level, value, score, criterion_code, ability_code
# 	E1 has the criteria 5.0
# 	E2 has the criteria 10.0
# 	E3 has the criteria 15.0
# 	E4 has the criteria 20.0
# 	E5 has the criteria 5.0
# 	E6 has the criteria 10.0
# 	E7 has the criteria 15.0
# 	E8 has the criteria 20.0
# 	E9 has the criteria 5.0
# 	E10 has the criteria 10.0
# 	E11 has the criteria 15.0
# 	E12 has the criteria 20.0
# 	E13 has the criteria 5.0
# 	E14 has the criteria 10.0
# 	E15 has the criteria 15.0
# 	E16 has the criteria 20.0
# 	E17 has the criteria 5.0
# 	E18 has the criteria 10.0
# 	E19 has the criteria 15.0
# 	E20 has the criteria 20.0
# 	E21 has the criteria 5.0
# 	E22 has the criteria 10.0
# 	E23 has the criteria 15.0
# 	E24 has the criteria 20.0
# 	E25 has the criteria 5.0
# 	E26 has the criteria 10.0
# 	E27 has the criteria 15.0
# 	E28 has the criteria 20.0
# 	E29 has the criteria 5.0
# 	E30 has the criteria 10.0
# 	E31 has the criteria 15.0
# 	E32 has the criteria 20.0
# 	E33 has the criteria 5.0
# 	E34 has the criteria 10.0
# 	E35 has the criteria 15.0
# 	E36 has the criteria 20.0
# 	E37 has the criteria 5.0
# 	E38 has the criteria 10.0
# 	E39 has the criteria 15.0
# 	E40 has the criteria 20.0
# 	E41 has the criteria 5.0
# 	E42 has the criteria 10.0
# 	E43 has the criteria 15.0
# 	E44 has the criteria 20.0
# 	E45 has the criteria 5.0
# 	E46 has the criteria 10.0
# 	E47 has the criteria 15.0
# 	E48 has the criteria 20.0
# 	E49 has the criteria 5.0
# 	E50 has the criteria 10.0
# 	E51 has the criteria 15.0
# 	E52 has the criteria 20.0
# 	E53 has the criteria 5.0
# 	E54 has the criteria 10.0
# 	E55 has the criteria 15.0
# 	E56 has the criteria 20.0
# 	E57 has the criteria 5.0
# 	E58 has the criteria 10.0
# 	E59 has the criteria 15.0
# 	E60 has the criteria 20.0
# 	E61 has the criteria 5.0
# 	E62 has the criteria 10.0
# 	E63 has the criteria 15.0
# 	E64 has the criteria 20.0
# 	E65 has the criteria 5.0
# 	E66 has the criteria 10.0
# 	E67 has the criteria 15.0
# 	E68 has the criteria 20.0
# 	E69 has the criteria 5.0
# 	E70 has the criteria 10.0
# 	E71 has the criteria 15.0
# 	E72 has the criteria 20.0
# 	E73 has the criteria 5.0
# 	E74 has the criteria 10.0
# 	E75 has the criteria 15.0
# 	E76 has the criteria 20.0
# 	E77 has the criteria 5.0
# 	E78 has the criteria 10.0
# 	E79 has the criteria 15.0
# 	E80 has the criteria 20.0
# 	E81 has the criteria 5.0
# 	E82 has the criteria 10.0
# 	E83 has the criteria 15.0
# 	E84 has the criteria 20.0
# 	E85 has the criteria 5.0
# 	E86 has the criteria 10.0
# 	E87 has the criteria 15.0
# 	E88 has the criteria 20.0
# 	E89 has the criteria 5.0
# 	E90 has the criteria 10.0
# 	E91 has the criteria 15.0
# 	E92 has the criteria 20.0
# 	E93 has the criteria 5.0
# 	E94 has the criteria 10.0
# 	E95 has the criteria 15.0
# 	E96 has the criteria 20.0
# 	E97 has the criteria 5.0
# 	E98 has the criteria 10.0
# 	E99 has the criteria 15.0
# 	E100 has the criteria 20.0
# 	E101 has the criteria 5.0
# 	E102 has the criteria 10.0
# 	E103 has the criteria 15.0
# 	E104 has the criteria 20.0
# 	E105 has the criteria 5.0
# 	E106 has the criteria 10.0
# 	E107 has the criteria 15.0
# 	E108 has the criteria 20.0
# 	E109 has the criteria 5.0
# 	E110 has the criteria 10.0
# 	E111 has the criteria 15.0
# 	E112 has the criteria 20.0
# 	E113 has the criteria 5.0
# 	E114 has the criteria 10.0
# 	E115 has the criteria 15.0
# 	E116 has the criteria 20.0
# 	E117 has the criteria 5.0
# 	E118 has the criteria 10.0
# 	E119 has the criteria 15.0
# 	E120 has the criteria 20.0
# 	E121 has the criteria 5.0
# 	E122 has the criteria 10.0
# 	E123 has the criteria 15.0
# 	E124 has the criteria 20.0
# 	E125 has the criteria 5.0
# 	E126 has the criteria 10.0
# 	E127 has the criteria 15.0
# 	E128 has the criteria 20.0
# 	E129 has the criteria 5.0
# 	E130 has the criteria 10.0
# 	E131 has the criteria 15.0
# 	E132 has the criteria 20.0
# 	E133 has the criteria 5.0
# 	E134 has the criteria 10.0
# 	E135 has the criteria 15.0
# 	E136 has the criteria 20.0
# 	E137 has the criteria 5.0
# 	E138 has the criteria 10.0
# 	E139 has the criteria 15.0
# 	E140 has the criteria 20.0
# 	E141 has the criteria 5.0
# 	E142 has the criteria 10.0
# 	E143 has the criteria 15.0
# 	E144 has the criteria 20.0
# 	E145 has the criteria 5.0
# 	E146 has the criteria 10.0
# 	E147 has the criteria 15.0
# 	E148 has the criteria 20.0
# 	E149 has the criteria 5.0
# 	E150 has the criteria 10.0
# 	E151 has the criteria 15.0
# 	E152 has the criteria 20.0
# 	E153 has the criteria 5.0
# 	E154 has the criteria 10.0
# 	E155 has the criteria 15.0
# 	E156 has the criteria 20.0
# 	E157 has the criteria 5.0
# 	E158 has the criteria 10.0
# 	E159 has the criteria 15.0
# 	E160 has the criteria 20.0
# 	E161 has the criteria 5.0
# 	E162 has the criteria 10.0
# 	E163 has the criteria 15.0
# 	E164 has the criteria 20.0
# 	E165 has the criteria 5.0
# 	E166 has the criteria 10.0
# 	E167 has the criteria 15.0
# 	E168 has the criteria 20.0
# Processed 169 lines.

# %%
#entrenar recomendador (! PENDIENTE: redondear parametros de entrada, revisar criterio de optimización)
num_users = len(user_data)
num_items = len(item_data)
embedding_dim = 128
#selección del modelo
model = recommender(num_users, num_items, embedding_dim)
#configuracion del criterio y su optimizador
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.5)

print(model)
#print(model.plan)
# Out:
# recommender(
#   (user_embedding): Embedding(35, 128)
#   (item_embedding): Embedding(168, 128)
#   (fc): Linear(in_features=256, out_features=1, bias=True)
# )

# %%
#solicitud para recomendacion (! PENDIENTE conectar con el Ruby)
recommendations = []
test_user = torch.LongTensor([0])  # Ingresamos "groupID" (indexado)

for i in item_data:
 test_item = torch.LongTensor([i])  # Ingresamos "code" (indexado)
 #iteraciones del modelo recomendador
 with torch.no_grad():
    recommendations.append(model(test_user, test_item))

# %%
#salida de depuración
matrix = [recommendations[i:i+8] for i in range(0, len(recommendations), 8)]
#matrix_df = pd.DataFrame(matrix)
#print(recommendations)
display(matrix)
# Out:
# [[tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657),
#   tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657)],
#  [tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657),
#   tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657)],
#  [tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657),
#   tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657)],
#  [tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657),
#   tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657)],
#  [tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657),
#   tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657)],
#  [tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657),
#   tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657)],
#  [tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657),
#   tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657)],
#  [tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657),
#   tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657)],
#  [tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657),
#   tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657)],
#  [tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657),
#   tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657)],
#  [tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657),
#   tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657)],
#  [tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657),
#   tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657)],
#  [tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657),
#   tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657)],
#  [tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657),
#   tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657)],
#  [tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657),
#   tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657)],
#  [tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657),
#   tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657)],
#  [tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657),
#   tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657)],
#  [tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657),
#   tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657)],
#  [tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657),
#   tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657)],
#  [tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657),
#   tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657)],
#  [tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657),
#   tensor(-0.7618),
#   tensor(-0.0103),
#   tensor(0.2706),
#   tensor(-0.8657)]]

# %%
port = 8000
url = ""
host = ""

# %%
#Configuración de API
app = FastAPI()

@app.route("/")
async def home():
    return "<h1>test</h1>"

@app.get("/")
async def read_root():
    return {"Hello": "World"}

@app.get("/getrec")
async def getrec():
   return IPython.display.JSON({'result': ' '.join((recommendations))})

try:
  print(recommendations)

except Exception as err:
  print(str(err))
# Out:
# [tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657), tensor(-0.7618), tensor(-0.0103), tensor(0.2706), tensor(-0.8657)]

# %%
if __name__ == "":
    app.run(debug=True, host=host, port=int(os.environ.get("PORT", 8000)))

# %%
import requests
from tenacity import (retry, stop_after_attempt, wait_fixed,
                      retry_if_exception_type)

@retry(stop=stop_after_attempt(3), wait=wait_fixed(0.1),
      retry=retry_if_exception_type(requests.HTTPError))
def get(url):
    try:
        r = requests.get(url)
        r.raise_for_status()  # raise an error on a bad status
        return r
    except requests.HTTPError:
        print(r.status_code, r.reason)
        raise

# %%
api_key = 'clavealeatoriadealtacalidad'
r = requests.get(url, auth=(api_key, ''))
